# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
exampleimg=cv2.imread("example-image.jpg")
# cvimage=cv2.cvtColor(exampleimg,cv2.COLOR_BGR2GRAY)

cv2.namedWindow("window", cv2.WINDOW_NORMAL)
cv2.resizeWindow("window", 400,512 )

# print(cvimage.shape)

cv2.imshow("window",exampleimg)
cv2.waitKey(0)
# Out:
# -1

# %%
blurred_img = cv2.GaussianBlur(exampleimg, (9, 9), 0)

cv2.namedWindow("window", cv2.WINDOW_NORMAL)
cv2.resizeWindow("window", 400,512 )
cv2.imshow("window",blurred_img)
cv2.waitKey(0)
# Out:
# -1

# %%
pd.DataFrame(cvimage.flatten())

# pxlofimage=pd.DataFrame(cvimage)
# pxlofimage
# Out:
#            0
# 0         85
# 1         85
# 2         85
# 3         86
# 4         87
# ...       ..
# 12533755  95
# 12533756  96
# 12533757  97
# 12533758  98
# 12533759  98
#
# [12533760 rows x 1 columns]

# %%
cvimage2=cv2.imread("example-image.jpg")
cvimage2.shape
# Out:
# (4080, 3072, 3)

# %%
cvimage2
# Out:
# array([[[ 69,  84,  93],
#         [ 69,  84,  93],
#         [ 69,  84,  93],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 84,  83,  85]],
#
#        [[ 69,  84,  93],
#         [ 68,  83,  92],
#         [ 68,  83,  92],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 85,  84,  86]],
#
#        [[ 69,  84,  93],
#         [ 68,  83,  92],
#         [ 68,  83,  92],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 85,  84,  86]],
#
#        ...,
#
#        [[ 54,  59,  62],
#         [ 55,  60,  63],
#         [ 57,  62,  65],
#         ...,
#         [ 86,  98, 104],
#         [ 87,  99, 105],
#         [ 87,  99, 105]],
#
#        [[ 55,  60,  63],
#         [ 56,  61,  64],
#         [ 57,  62,  65],
#         ...,
#         [ 86,  96, 103],
#         [ 86,  98, 104],
#         [ 87,  99, 105]],
#
#        [[ 55,  60,  63],
#         [ 56,  61,  64],
#         [ 58,  63,  66],
# ...

# %%
import pandas as pd

df=pd.Series(cvimage2.flatten())
df
# Out:
# 0            69
# 1            84
# 2            93
# 3            69
# 4            84
#            ...
# 37601275     98
# 37601276    104
# 37601277     86
# 37601278     98
# 37601279    104
# Length: 37601280, dtype: uint8

# %%
import matplotlib.pyplot as plt

df.plot(kind='hist',bins=50,title='Pixel values') 
plt.show()

# %%
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].imshow(cvimage2[:,:,0],cmap='Reds')
axs[1].imshow(cvimage2[:,:,1],cmap='Greens')
axs[2].imshow(cvimage2[:,:,2],cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.imshow(cvimage2)
plt.show()

# %%
cv2imagegray=cv2.cvtColor(exampleimg,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,5))
plt.imshow(cv2imagegray,cmap='gray')
plt.show()

# %% [markdown]
# # Blurring (Gaussian blur)

# %%
blur = cv2.GaussianBlur(exampleimg,(5,5),0)
blur
# Out:
# array([[[ 69,  84,  93],
#         [ 69,  84,  93],
#         [ 69,  84,  93],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 84,  83,  85]],
#
#        [[ 69,  84,  93],
#         [ 69,  84,  93],
#         [ 69,  84,  93],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 84,  83,  85]],
#
#        [[ 70,  85,  93],
#         [ 69,  84,  93],
#         [ 69,  84,  93],
#         ...,
#         [ 83,  82,  84],
#         [ 84,  83,  85],
#         [ 84,  83,  85]],
#
#        ...,
#
#        [[ 55,  60,  63],
#         [ 56,  61,  64],
#         [ 57,  62,  65],
#         ...,
#         [ 86,  97, 103],
#         [ 86,  98, 104],
#         [ 86,  98, 104]],
#
#        [[ 56,  61,  64],
#         [ 56,  61,  64],
#         [ 57,  62,  65],
#         ...,
#         [ 86,  97, 103],
#         [ 86,  98, 104],
#         [ 86,  98, 104]],
#
#        [[ 56,  61,  64],
#         [ 56,  61,  64],
#         [ 57,  62,  65],
# ...

# %%
blur = cv2.GaussianBlur(exampleimg,(5,5),0)
 
plt.subplot(121),plt.imshow(exampleimg),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np

image = cv2.imread('example-image.jpg')

sharpening_kernel = np.array([[-1, -1, -1],
                             [-1, 9, -1],
                             [-1, -1, -1]])
sharpened_image = cv2.filter2D(image, -1, sharpening_kernel)

cvimage=cv2.cvtColor(sharpened_image,cv2.COLOR_BGR2GRAY)

cv2.namedWindow("window", cv2.WINDOW_NORMAL)
x=cv2.resizeWindow("window", 400,512 )

cv2.imshow("window", cvimage)
cv2.waitKey(0)
# Out:
# -1

# %%
equ = cv2.equalizeHist()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~inja2 (C:\Users\hp\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~inja2 (C:\Users\hp\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~inja2 (C:\Users\hp\AppData\Roaming\Python\Python312\site-packages)

# %% [markdown]
# # Why I'm not using Edge detection?
#   source: https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
 
img = cv.imread('example-image.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
edges = cv.Canny(img,100,200)
 
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
 
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Load the image in grayscale
img = cv2.imread("IMG_20241102_173526591.jpg")
assert img is not None, "File could not be read, check with os.path.exists()"

resized_img = cv2.resize(img, (2048, 2048))

rgb_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)

gray_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2GRAY)
blurred_img = cv2.GaussianBlur(gray_img, (5, 5), sigmaX=1.0, sigmaY=1.0)
            
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_img = clahe.apply(gray_img)

                                                                            # blurred_img = cv2.GaussianBlur(gray_img, (9, 9), 0)

                                                                            # source for sharpening images: https://medium.com/@sajjadhadi/mastering-opencv2-in-15-days-day-3-image-filtering-and-enhancement-ae1095f09aa5

sharpening_kernel = np.array([[-1, -1, -1],
                             [-1, 9, -1],
                             [-1, -1, -1]])
sharpened_image = cv2.filter2D(clahe_img, -1, sharpening_kernel)

# Step 1: Apply Gaussian Blurring to reduce noise
blurred_img = cv2.GaussianBlur(img, (5, 5), sigmaX=1.0, sigmaY=1.0)

# Step 2: Compute gradients using Sobel filter (for more control over edge detection)
sobelx = cv2.Sobel(blurred_img, cv2.CV_64F, 1, 0, ksize=3)  # Gradient in X direction
sobely = cv2.Sobel(blurred_img, cv2.CV_64F, 0, 1, ksize=3)  # Gradient in Y direction

# Calculate gradient magnitude
gradient_magnitude = np.hypot(sobelx, sobely)
gradient_magnitude = np.uint8(255 * gradient_magnitude / np.max(gradient_magnitude))

normalized_img = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX)
normalized_img = np.uint8(normalized_img)

# Step 3: Use Canny Edge Detection with improved thresholds based on gradient magnitude
# Using mean value of gradient magnitude for adaptive thresholding
mean_grad = np.mean(gradient_magnitude)
lower_threshold = mean_grad * 0.5
upper_threshold = mean_grad * 1.5
edges = cv2.Canny(blurred_img, lower_threshold, upper_threshold)

# Display the results
plt.figure(figsize=(10, 5))
plt.subplot(131), plt.imshow(rgb_img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(normalized_img, cmap='gray')
plt.title('Gradient Magnitude'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(edges, cmap='gray')
plt.title('Enhanced Edge Image'), plt.xticks([]), plt.yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# If the areca nut's position is fairly consistent but varies slightly, you might instead consider using Cropping or Region of Interest (ROI) techniques to focus directly on the nut itself.

# %% [markdown]
# ## Image ROI
#
# sorce: https://docs.opencv.org/4.x/d3/df2/tutorial_py_basic_ops.html
#
# Sometimes, you will have to play with certain regions of images. For eye detection in images, first face detection is done over the entire image. When a face is obtained, we select the face region alone and search for eyes inside it instead of searching the whole image. It improves accuracy (because eyes are always on faces :D ) and performance (because we search in a small area).
#
# ROI is again obtained using Numpy indexing. Here I am selecting the ball and copying it to another region in the image:
#
# >>> ball = img[280:340, 330:390]
# >>> img[273:333, 100:160] = ball

# %% [markdown]
# ## image segmentation for arecanut
#
# Using segmentation techniques (like U-Net or Mask R-CNN) to isolate the areca nut from the background can enhance the quality of your dataset.
#
# 1. Getting Started with Mask R-CNN for Instance Segmentation
# https://www.mathworks.com/help/vision/ug/getting-started-with-mask-r-cnn-for-instance-segmentation.html
#
# 2. Segmentation: U-Net, Mask R-CNN, and Medical Applications
# https://glassboxmedicine.com/2020/01/21/segmentation-u-net-mask-r-cnn-and-medical-applications/
#
# 3. U-Net Architecture For Image Segmentation
# https://www.digitalocean.com/community/tutorials/unet-architecture-image-segmentation
